# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load the data
jobs = pd.read_csv("C:/Users/sneha/Downloads/Candidate matching/job_data_merged_1.csv")
candidates = pd.read_csv("C:/Users/sneha/Downloads/Candidate matching/gpt_dataset.csv")

# Display the first few rows of the data
print(jobs.head())
print(candidates.head())
# Out:
#    Unnamed: 0          Category Workplace  \
# 0           0  Business Analyst    Remote
# 1           1  Business Analyst    Remote
# 2           2  Business Analyst   On-site
# 3           3  Business Analyst   On-site
# 4           4  Business Analyst    Remote
#
#                                        Location             Department  \
# 0                                United Kingdom             Operations
# 1             Makati, Metro Manila, Philippines                 Aux HQ
# 2  Al-Dajeej, Al Farwaniyah Governorate, Kuwait       PWC Technologies
# 3               London, England, United Kingdom  Consultants, Advisory
# 4                                United Kingdom             Operations
#
#         Type
# 0  Full time
# 1  Full time
# 2  Full time
# 3  Full time
# 4  Full time
#              Category                                             Resume
# 0  Frontend Developer  As a seasoned Frontend Developer, I have a pro...
# 1   Backend Developer  With a solid background in Backend Development...
# 2    Python Developer  As a Python Developer, I leverage my expertise...
# 3      Data Scientist  With a background in Data Science, I possess a...
# 4  Frontend Developer  Experienced Frontend Developer with a passion ...

# %%
# Handle missing values
jobs.fillna('', inplace=True)
candidates.fillna('', inplace=True)

# Download NLTK data
nltk.download('stopwords')
nltk.download('wordnet')

# Function to preprocess text
def preprocess_text(text):
    text = re.sub(r'\W', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    text = text.lower().strip()
    words = text.split()
    words = [word for word in words if word not in stopwords.words('english')]
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(words)

# Apply preprocessing to relevant columns
jobs['Category'] = jobs['Category'].apply(preprocess_text)
jobs['Workplace'] = jobs['Workplace'].apply(preprocess_text)
jobs['Location'] = jobs['Location'].apply(preprocess_text)
jobs['Department'] = jobs['Department'].apply(preprocess_text)
jobs['Type'] = jobs['Type'].apply(preprocess_text)
candidates['Resume'] = candidates['Resume'].apply(preprocess_text)

# Combine job attributes into one text field
jobs['combined'] = jobs['Category'] + ' ' + jobs['Workplace'] + ' ' + jobs['Location'] + ' ' + jobs['Department'] + ' ' + jobs['Type']

# Display the first few rows to verify
print(jobs.head())
print(candidates.head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sneha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sneha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#    Unnamed: 0          Category Workplace  \
# 0           0  business analyst    remote
# 1           1  business analyst    remote
# 2           2  business analyst      site
# 3           3  business analyst      site
# 4           4  business analyst    remote
#
#                                      Location           Department       Type  \
# 0                              united kingdom            operation  full time
# 1              makati metro manila philippine               aux hq  full time
# 2  al dajeej al farwaniyah governorate kuwait       pwc technology  full time
# 3               london england united kingdom  consultant advisory  full time
# 4                              united kingdom            operation  full time
#
#                                             combined
# 0  business analyst remote united kingdom operati...
# 1  business analyst remote makati metro manila ph...
# 2  business analyst site al dajeej al farwaniyah ...
# 3  business analyst site london england united ki...
# 4  business analyst remote united kingdom operati...
#              Category                                             Resume
# 0  Frontend Developer  seasoned frontend developer proven track recor...
# 1   Backend Developer  solid background backend development bring 7 y...
# 2    Python Developer  python developer leverage expertise python pro...
# 3      Data Scientist  background data science posse unique blend ana...
# 4  Frontend Developer  experienced frontend developer passion craftin...

# %%
# Vectorize the combined job descriptions and candidate resumes
vectorizer = TfidfVectorizer(max_features=5000)
job_features = vectorizer.fit_transform(jobs['combined']).toarray()
candidate_features = vectorizer.transform(candidates['Resume']).toarray()

# Print shape of feature matrices to debug
print("Job features shape:", job_features.shape)
print("Candidate features shape:", candidate_features.shape)
# Out:
# Job features shape: (1095, 705)
# Candidate features shape: (400, 705)

# %%
# Calculate cosine similarity between candidates and jobs
similarity_matrix = cosine_similarity(candidate_features, job_features)

# Print similarity matrix to debug
print("Similarity matrix:", similarity_matrix)
# Out:
# Similarity matrix: [[0.00864636 0.0048747  0.00366521 ... 0.06303141 0.14519842 0.08105911]
#  [0.05114574 0.02883526 0.05086385 ... 0.00588803 0.00349973 0.06807685]
#  [0.         0.         0.03073701 ... 0.         0.         0.06372656]
#  ...
#  [0.00740323 0.00417384 0.07696924 ... 0.00505942 0.00300722 0.15957914]
#  [0.0208195  0.01173775 0.04375471 ... 0.01422821 0.00845696 0.09071597]
#  [0.00576158 0.0032483  0.04074844 ... 0.00393751 0.00234038 0.08448311]]

# %%
# Find the best job match for each candidate
best_matches = similarity_matrix.argmax(axis=1)
candidates['best_job_id'] = best_matches

# Print the matched job for each candidate to debug
for i in range(len(candidates)):
    print(f"Candidate {i+1} is best matched with Job {candidates['best_job_id'][i]}")
# Out:
# Candidate 1 is best matched with Job 1061
# Candidate 2 is best matched with Job 135
# Candidate 3 is best matched with Job 515
# Candidate 4 is best matched with Job 427
# Candidate 5 is best matched with Job 1061
# Candidate 6 is best matched with Job 135
# Candidate 7 is best matched with Job 911
# Candidate 8 is best matched with Job 135
# Candidate 9 is best matched with Job 135
# Candidate 10 is best matched with Job 135
# Candidate 11 is best matched with Job 427
# Candidate 12 is best matched with Job 427
# Candidate 13 is best matched with Job 1061
# Candidate 14 is best matched with Job 135
# Candidate 15 is best matched with Job 135
# Candidate 16 is best matched with Job 427
# Candidate 17 is best matched with Job 427
# Candidate 18 is best matched with Job 135
# Candidate 19 is best matched with Job 135
# Candidate 20 is best matched with Job 135
# Candidate 21 is best matched with Job 427
# Candidate 22 is best matched with Job 427
# Candidate 23 is best matched with Job 135
# Candidate 24 is best matched with Job 135
# Candidate 25 is best matched with Job 135
# Candidate 26 is best matched with Job 427
# Candidate 27 is best matched with Job 427
# Candidate 28 is best matched with Job 627
# Candidate 29 is best matched with Job 627
# Candidate 30 is best matched with Job 627
# Candidate 31 is best matched with Job 956
# Candidate 32 is best matched with Job 423
# Candidate 33 is best matched with Job 627
# Candidate 34 is best matched with Job 627
# Candidate 35 is best matched with Job 423
# Candidate 36 is best matched with Job 956
# Candidate 37 is best matched with Job 627
# Candidate 38 is best matched with Job 423
# Candidate 39 is best matched with Job 627
# Candidate 40 is best matched with Job 423
# Candidate 41 is best matched with Job 956
# Candidate 42 is best matched with Job 627
# Candidate 43 is best matched with Job 423
# Candidate 44 is best matched with Job 427
# Candidate 45 is best matched with Job 427
# Candidate 46 is best matched with Job 427
# Candidate 47 is best matched with Job 427
# Candidate 48 is best matched with Job 427
# Candidate 49 is best matched with Job 427
# Candidate 50 is best matched with Job 427
# Candidate 51 is best matched with Job 427
# Candidate 52 is best matched with Job 427
# Candidate 53 is best matched with Job 427
# Candidate 54 is best matched with Job 427
# Candidate 55 is best matched with Job 427
# Candidate 56 is best matched with Job 427
# Candidate 57 is best matched with Job 427
# Candidate 58 is best matched with Job 427
# Candidate 59 is best matched with Job 275
# Candidate 60 is best matched with Job 275
# Candidate 61 is best matched with Job 275
# Candidate 62 is best matched with Job 275
# Candidate 63 is best matched with Job 275
# Candidate 64 is best matched with Job 275
# Candidate 65 is best matched with Job 275
# Candidate 66 is best matched with Job 275
# Candidate 67 is best matched with Job 275
# Candidate 68 is best matched with Job 275
# Candidate 69 is best matched with Job 275
# Candidate 70 is best matched with Job 275
# Candidate 71 is best matched with Job 275
# Candidate 72 is best matched with Job 275
# Candidate 73 is best matched with Job 275
# Candidate 74 is best matched with Job 275
# Candidate 75 is best matched with Job 423
# Candidate 76 is best matched with Job 423
# Candidate 77 is best matched with Job 423
# Candidate 78 is best matched with Job 423
# Candidate 79 is best matched with Job 423
# Candidate 80 is best matched with Job 423
# Candidate 81 is best matched with Job 423
# Candidate 82 is best matched with Job 423
# Candidate 83 is best matched with Job 423
# Candidate 84 is best matched with Job 423
# Candidate 85 is best matched with Job 423
# Candidate 86 is best matched with Job 423
# Candidate 87 is best matched with Job 423
# Candidate 88 is best matched with Job 423
# Candidate 89 is best matched with Job 423
# Candidate 90 is best matched with Job 423
# Candidate 91 is best matched with Job 423
# Candidate 92 is best matched with Job 423
# Candidate 93 is best matched with Job 423
# Candidate 94 is best matched with Job 423
# Candidate 95 is best matched with Job 423
# Candidate 96 is best matched with Job 423
# Candidate 97 is best matched with Job 423
# Candidate 98 is best matched with Job 423
# Candidate 99 is best matched with Job 423
# Candidate 100 is best matched with Job 423
# Candidate 101 is best matched with Job 423
# Candidate 102 is best matched with Job 423
# Candidate 103 is best matched with Job 423
# Candidate 104 is best matched with Job 423
# Candidate 105 is best matched with Job 423
# Candidate 106 is best matched with Job 423
# Candidate 107 is best matched with Job 423
# Candidate 108 is best matched with Job 423
# Candidate 109 is best matched with Job 423
# Candidate 110 is best matched with Job 423
# Candidate 111 is best matched with Job 423
# Candidate 112 is best matched with Job 423
# Candidate 113 is best matched with Job 423
# Candidate 114 is best matched with Job 423
# Candidate 115 is best matched with Job 423
# Candidate 116 is best matched with Job 423
# Candidate 117 is best matched with Job 423
# Candidate 118 is best matched with Job 423
# Candidate 119 is best matched with Job 423
# Candidate 120 is best matched with Job 427
# Candidate 121 is best matched with Job 427
# Candidate 122 is best matched with Job 423
# Candidate 123 is best matched with Job 423
# Candidate 124 is best matched with Job 427
# Candidate 125 is best matched with Job 427
# Candidate 126 is best matched with Job 423
# Candidate 127 is best matched with Job 423
# Candidate 128 is best matched with Job 427
# Candidate 129 is best matched with Job 427
# Candidate 130 is best matched with Job 423
# Candidate 131 is best matched with Job 423
# Candidate 132 is best matched with Job 427
# Candidate 133 is best matched with Job 427
# Candidate 134 is best matched with Job 427
# Candidate 135 is best matched with Job 423
# Candidate 136 is best matched with Job 427
# Candidate 137 is best matched with Job 427
# Candidate 138 is best matched with Job 427
# Candidate 139 is best matched with Job 423
# Candidate 140 is best matched with Job 427
# Candidate 141 is best matched with Job 427
# Candidate 142 is best matched with Job 427
# Candidate 143 is best matched with Job 423
# Candidate 144 is best matched with Job 427
# Candidate 145 is best matched with Job 427
# Candidate 146 is best matched with Job 423
# Candidate 147 is best matched with Job 423
# Candidate 148 is best matched with Job 427
# Candidate 149 is best matched with Job 427
# Candidate 150 is best matched with Job 423
# Candidate 151 is best matched with Job 423
# Candidate 152 is best matched with Job 427
# Candidate 153 is best matched with Job 427
# Candidate 154 is best matched with Job 423
# Candidate 155 is best matched with Job 423
# Candidate 156 is best matched with Job 423
# Candidate 157 is best matched with Job 423
# Candidate 158 is best matched with Job 423
# Candidate 159 is best matched with Job 423
# Candidate 160 is best matched with Job 627
# Candidate 161 is best matched with Job 423
# Candidate 162 is best matched with Job 423
# Candidate 163 is best matched with Job 423
# Candidate 164 is best matched with Job 627
# Candidate 165 is best matched with Job 423
# Candidate 166 is best matched with Job 423
# Candidate 167 is best matched with Job 423
# Candidate 168 is best matched with Job 627
# Candidate 169 is best matched with Job 423
# Candidate 170 is best matched with Job 423
# Candidate 171 is best matched with Job 423
# Candidate 172 is best matched with Job 627
# Candidate 173 is best matched with Job 780
# Candidate 174 is best matched with Job 427
# Candidate 175 is best matched with Job 627
# Candidate 176 is best matched with Job 627
# Candidate 177 is best matched with Job 780
# Candidate 178 is best matched with Job 427
# Candidate 179 is best matched with Job 627
# Candidate 180 is best matched with Job 627
# Candidate 181 is best matched with Job 780
# Candidate 182 is best matched with Job 427
# Candidate 183 is best matched with Job 627
# Candidate 184 is best matched with Job 627
# Candidate 185 is best matched with Job 780
# Candidate 186 is best matched with Job 427
# Candidate 187 is best matched with Job 627
# Candidate 188 is best matched with Job 427
# Candidate 189 is best matched with Job 427
# Candidate 190 is best matched with Job 427
# Candidate 191 is best matched with Job 427
# Candidate 192 is best matched with Job 427
# Candidate 193 is best matched with Job 427
# Candidate 194 is best matched with Job 427
# Candidate 195 is best matched with Job 427
# Candidate 196 is best matched with Job 427
# Candidate 197 is best matched with Job 427
# Candidate 198 is best matched with Job 427
# Candidate 199 is best matched with Job 427
# Candidate 200 is best matched with Job 275
# Candidate 201 is best matched with Job 275
# Candidate 202 is best matched with Job 275
# Candidate 203 is best matched with Job 275
# Candidate 204 is best matched with Job 275
# Candidate 205 is best matched with Job 275
# Candidate 206 is best matched with Job 275
# Candidate 207 is best matched with Job 275
# Candidate 208 is best matched with Job 275
# Candidate 209 is best matched with Job 275
# Candidate 210 is best matched with Job 275
# Candidate 211 is best matched with Job 275
# Candidate 212 is best matched with Job 423
# Candidate 213 is best matched with Job 423
# Candidate 214 is best matched with Job 423
# Candidate 215 is best matched with Job 423
# Candidate 216 is best matched with Job 423
# Candidate 217 is best matched with Job 423
# Candidate 218 is best matched with Job 423
# Candidate 219 is best matched with Job 423
# Candidate 220 is best matched with Job 423
# Candidate 221 is best matched with Job 423
# Candidate 222 is best matched with Job 423
# Candidate 223 is best matched with Job 423
# Candidate 224 is best matched with Job 423
# Candidate 225 is best matched with Job 423
# Candidate 226 is best matched with Job 423
# Candidate 227 is best matched with Job 423
# Candidate 228 is best matched with Job 423
# Candidate 229 is best matched with Job 423
# Candidate 230 is best matched with Job 423
# Candidate 231 is best matched with Job 423
# Candidate 232 is best matched with Job 423
# Candidate 233 is best matched with Job 423
# Candidate 234 is best matched with Job 423
# Candidate 235 is best matched with Job 423
# Candidate 236 is best matched with Job 423
# Candidate 237 is best matched with Job 423
# Candidate 238 is best matched with Job 423
# Candidate 239 is best matched with Job 423
# Candidate 240 is best matched with Job 427
# Candidate 241 is best matched with Job 427
# Candidate 242 is best matched with Job 427
# Candidate 243 is best matched with Job 427
# Candidate 244 is best matched with Job 427
# Candidate 245 is best matched with Job 427
# Candidate 246 is best matched with Job 427
# Candidate 247 is best matched with Job 427
# Candidate 248 is best matched with Job 427
# Candidate 249 is best matched with Job 427
# Candidate 250 is best matched with Job 427
# Candidate 251 is best matched with Job 427
# Candidate 252 is best matched with Job 427
# Candidate 253 is best matched with Job 427
# Candidate 254 is best matched with Job 427
# Candidate 255 is best matched with Job 427
# Candidate 256 is best matched with Job 275
# Candidate 257 is best matched with Job 275
# Candidate 258 is best matched with Job 275
# Candidate 259 is best matched with Job 275
# Candidate 260 is best matched with Job 275
# Candidate 261 is best matched with Job 275
# Candidate 262 is best matched with Job 275
# Candidate 263 is best matched with Job 275
# Candidate 264 is best matched with Job 275
# Candidate 265 is best matched with Job 275
# Candidate 266 is best matched with Job 275
# Candidate 267 is best matched with Job 275
# Candidate 268 is best matched with Job 427
# Candidate 269 is best matched with Job 427
# Candidate 270 is best matched with Job 427
# Candidate 271 is best matched with Job 352
# Candidate 272 is best matched with Job 427
# Candidate 273 is best matched with Job 427
# Candidate 274 is best matched with Job 427
# Candidate 275 is best matched with Job 352
# Candidate 276 is best matched with Job 427
# Candidate 277 is best matched with Job 427
# Candidate 278 is best matched with Job 427
# Candidate 279 is best matched with Job 352
# Candidate 280 is best matched with Job 427
# Candidate 281 is best matched with Job 427
# Candidate 282 is best matched with Job 427
# Candidate 283 is best matched with Job 352
# Candidate 284 is best matched with Job 423
# Candidate 285 is best matched with Job 423
# Candidate 286 is best matched with Job 423
# Candidate 287 is best matched with Job 423
# Candidate 288 is best matched with Job 423
# Candidate 289 is best matched with Job 423
# Candidate 290 is best matched with Job 423
# Candidate 291 is best matched with Job 423
# Candidate 292 is best matched with Job 423
# Candidate 293 is best matched with Job 423
# Candidate 294 is best matched with Job 423
# Candidate 295 is best matched with Job 423
# Candidate 296 is best matched with Job 423
# Candidate 297 is best matched with Job 423
# Candidate 298 is best matched with Job 423
# Candidate 299 is best matched with Job 423
# Candidate 300 is best matched with Job 423
# Candidate 301 is best matched with Job 423
# Candidate 302 is best matched with Job 423
# Candidate 303 is best matched with Job 423
# Candidate 304 is best matched with Job 996
# Candidate 305 is best matched with Job 996
# Candidate 306 is best matched with Job 284
# Candidate 307 is best matched with Job 423
# Candidate 308 is best matched with Job 996
# Candidate 309 is best matched with Job 996
# Candidate 310 is best matched with Job 284
# Candidate 311 is best matched with Job 423
# Candidate 312 is best matched with Job 996
# Candidate 313 is best matched with Job 996
# Candidate 314 is best matched with Job 284
# Candidate 315 is best matched with Job 423
# Candidate 316 is best matched with Job 996
# Candidate 317 is best matched with Job 996
# Candidate 318 is best matched with Job 284
# Candidate 319 is best matched with Job 423
# Candidate 320 is best matched with Job 423
# Candidate 321 is best matched with Job 423
# Candidate 322 is best matched with Job 423
# Candidate 323 is best matched with Job 423
# Candidate 324 is best matched with Job 423
# Candidate 325 is best matched with Job 423
# Candidate 326 is best matched with Job 275
# Candidate 327 is best matched with Job 423
# Candidate 328 is best matched with Job 423
# Candidate 329 is best matched with Job 423
# Candidate 330 is best matched with Job 956
# Candidate 331 is best matched with Job 423
# Candidate 332 is best matched with Job 423
# Candidate 333 is best matched with Job 423
# Candidate 334 is best matched with Job 275
# Candidate 335 is best matched with Job 423
# Candidate 336 is best matched with Job 780
# Candidate 337 is best matched with Job 423
# Candidate 338 is best matched with Job 423
# Candidate 339 is best matched with Job 423
# Candidate 340 is best matched with Job 996
# Candidate 341 is best matched with Job 423
# Candidate 342 is best matched with Job 627
# Candidate 343 is best matched with Job 1058
# Candidate 344 is best matched with Job 911
# Candidate 345 is best matched with Job 423
# Candidate 346 is best matched with Job 423
# Candidate 347 is best matched with Job 423
# Candidate 348 is best matched with Job 996
# Candidate 349 is best matched with Job 423
# Candidate 350 is best matched with Job 627
# Candidate 351 is best matched with Job 427
# Candidate 352 is best matched with Job 427
# Candidate 353 is best matched with Job 423
# Candidate 354 is best matched with Job 423
# Candidate 355 is best matched with Job 427
# Candidate 356 is best matched with Job 423
# Candidate 357 is best matched with Job 427
# Candidate 358 is best matched with Job 423
# Candidate 359 is best matched with Job 427
# Candidate 360 is best matched with Job 423
# Candidate 361 is best matched with Job 427
# Candidate 362 is best matched with Job 423
# Candidate 363 is best matched with Job 427
# Candidate 364 is best matched with Job 423
# Candidate 365 is best matched with Job 427
# Candidate 366 is best matched with Job 427
# Candidate 367 is best matched with Job 427
# Candidate 368 is best matched with Job 352
# Candidate 369 is best matched with Job 427
# Candidate 370 is best matched with Job 427
# Candidate 371 is best matched with Job 427
# Candidate 372 is best matched with Job 423
# Candidate 373 is best matched with Job 352
# Candidate 374 is best matched with Job 427
# Candidate 375 is best matched with Job 352
# Candidate 376 is best matched with Job 352
# Candidate 377 is best matched with Job 427
# Candidate 378 is best matched with Job 427
# Candidate 379 is best matched with Job 427
# Candidate 380 is best matched with Job 423
# Candidate 381 is best matched with Job 352
# Candidate 382 is best matched with Job 275
# Candidate 383 is best matched with Job 275
# Candidate 384 is best matched with Job 275
# Candidate 385 is best matched with Job 275
# Candidate 386 is best matched with Job 275
# Candidate 387 is best matched with Job 259
# Candidate 388 is best matched with Job 423
# Candidate 389 is best matched with Job 275
# Candidate 390 is best matched with Job 275
# Candidate 391 is best matched with Job 259
# Candidate 392 is best matched with Job 423
# Candidate 393 is best matched with Job 275
# Candidate 394 is best matched with Job 275
# Candidate 395 is best matched with Job 259
# Candidate 396 is best matched with Job 423
# Candidate 397 is best matched with Job 275
# Candidate 398 is best matched with Job 423
# Candidate 399 is best matched with Job 423
# Candidate 400 is best matched with Job 423
